# %%
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk import LancasterStemmer
from nltk.stem import RegexpStemmer

# %%
ps = PorterStemmer()
snow_stemmer = SnowballStemmer(language='english')
Lanc = LancasterStemmer()
st = RegexpStemmer('ing$|s$|e$|able$', min=4)

print("** PORT STEMMER **")
with open('words_alpha.txt','r') as file:
    for index, line in enumerate(file):
        if index >= 110:
            break
        if index >= 100:
            word = line.strip()
            stemmed_word = ps.stem(word)
            print(f"{word} : {stemmed_word}")
# Out:
# ** PORT STEMMER **
# abanga : abanga
# abanic : aban
# abannition : abannit
# abantes : abant
# abapical : abap
# abaptiston : abaptiston
# abaptistum : abaptistum
# abarambo : abarambo
# abaris : abari
# abarthrosis : abarthrosi

# %%
print("** SNOWBALL STEMMER**")
with open('words_alpha.txt','r') as file:
    for index, line in enumerate(file):
        if index >= 110:
            break
        if index >= 100:
            word = line.strip()
            snow_word = snow_stemmer.stem(word)
            print(f"{word} : {snow_word}")
# Out:
# ** SNOWBALL STEMMER**
# abanga : abanga
# abanic : aban
# abannition : abannit
# abantes : abant
# abapical : abap
# abaptiston : abaptiston
# abaptistum : abaptistum
# abarambo : abarambo
# abaris : abari
# abarthrosis : abarthrosi

# %%
print("** LANDCASTER STEMMER**")
with open('words_alpha.txt','r') as file:
    for index, line in enumerate(file):
        if index >= 110:
            break
        if index >= 100:
            word = line.strip()
            print(word , " : ", Lanc.stem(word))
# Out:
# ** LANDCASTER STEMMER**
# abanga  :  abang
# abanic  :  ab
# abannition  :  abannit
# abantes  :  ab
# abapical  :  abap
# abaptiston  :  abaptiston
# abaptistum  :  abaptist
# abarambo  :  abarambo
# abaris  :  ab
# abarthrosis  :  abarthros

# %%
print("** REGEXP STEMMER**")
with open('words_alpha.txt','r') as file:
    for index, line in enumerate(file):
        if index >= 110:
            break
        if index >= 100:
            word = line.strip()
            print(f"{word} : {st.stem(word)}")
# Out:
# ** REGEXP STEMMER**
# abanga : abanga
# abanic : abanic
# abannition : abannition
# abantes : abante
# abapical : abapical
# abaptiston : abaptiston
# abaptistum : abaptistum
# abarambo : abarambo
# abaris : abari
# abarthrosis : abarthrosi
